# %% [markdown]
# ## Studio onde a diversi hz

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import signal

# %% [markdown]
# ## Varibili per creare un segnale nel tempo

# %%
# Frenquenza in Hz
freq = 0
#Durata in secondi
durata = 1
#frequenza campionamento (al secondo)
fs = 100
#array per il tempo
t = np.linspace(0, durata, int(fs*durata))

# %% [markdown]
# ## Onda Sinusoidale

# %% [markdown]
# ### 100 hz

# %%
freq = 100
plt.plot(t, np.sin(2*np.pi*freq*t))
plt.xlabel('Tempo (s)')
plt.ylabel('Ampiezza')
plt.title('Onda Sinusoidale - 100 Hz')
plt.show()

# %% [markdown]
# ### 200 hz

# %%
freq = 200
plt.plot(t ,np.sin(2*np.pi*freq*t))
plt.xlabel('Tempo (s)')
plt.ylabel('Ampiezza')
plt.title('Onda Sinusoidale - 200 Hz')
plt.show()
plt.show()

# %% [markdown]
# ### 440 hz

# %%
freq = 440
plt.plot(t ,np.sin(2*np.pi*freq*t))
plt.xlabel('Tempo (s)')
plt.ylabel('Ampiezza')
plt.title('Onda Sinusoidale - 440 Hz')
plt.show()
plt.show()

# %% [markdown]
# ## Onda Triangolare

# %% [markdown]
# ### 100 hz

# %%
freq = 100
plt.plot(t, signal.sawtooth(2*np.pi*freq*t, 0.5))
plt.xlabel('Tempo (s)')
plt.ylabel('Ampiezza')
plt.title('Onda Triangolare - 100 Hz')
plt.show()

# %% [markdown]
# ### 200 hz

# %%
freq = 200
plt.plot(t, signal.sawtooth(2*np.pi*freq*t, 0.5))
plt.xlabel('Tempo (s)')
plt.ylabel('Ampiezza')
plt.title('Onda Triangolare - 200 Hz')
plt.show()

# %% [markdown]
# ### 440 hz

# %%
freq = 440
plt.plot(t, signal.sawtooth(2*np.pi*freq*t, 0.5))
plt.xlabel('Tempo (s)')
plt.ylabel('Ampiezza')
plt.title('Onda Triangolare - 440 Hz')
plt.show()

# %% [markdown]
# ## Onda quadra

# %% [markdown]
# ### 100 hz

# %%
freq = 100
plt.plot(t, signal.square(2*np.pi*freq*t))
plt.xlabel('Tempo (s)')
plt.ylabel('Ampiezza')
plt.title('Onda Quadra - 100 Hz')
plt.show()

# %% [markdown]
# ### 200 hz

# %%
freq = 200
plt.plot(t, signal.square(2*np.pi*freq*t))
plt.xlabel('Tempo (s)')
plt.ylabel('Ampiezza')
plt.title('Onda Quadra - 200 Hz')
plt.show()

# %% [markdown]
# ### 440 hz

# %%
freq = 440
plt.plot(t, signal.square(2*np.pi*freq*t))
plt.xlabel('Tempo (s)')
plt.ylabel('Ampiezza')
plt.title('Onda Quadra - 440 Hz')
plt.show()
